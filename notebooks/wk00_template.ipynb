# %% [markdown]
# # 주차별 노트북 템플릿
#
# 원칙: 노트북은 `src/sdkb_paper` 모듈을 **호출만** 한다. 로직을 노트북에 쌓지 말 것.
# 이 파일을 복사해 `wk04_eda_coverage_gap.ipynb` 처럼 사용.

# %%
# --- Colab 부트스트랩 (로컬에서는 이 셀 건너뜀) ---
import sys
if 'google.colab' in sys.modules:
    from google.colab import userdata
    token = userdata.get('GH_TOKEN')  # fine-grained PAT, Colab Secrets 에 저장
    # !git clone https://{token}@github.com/arkwith7/sdkb-foresight-paper.git
    # %cd sdkb-foresight-paper
    # %pip install -q -e .
    import os
    os.environ['KIPRIS_API_KEY'] = userdata.get('KIPRIS_API_KEY')

# %%
from sdkb_paper.config import SAMPLES
from sdkb_paper.analysis.coverage import coverage_by_process_step

coverage_by_process_step(SAMPLES / 'mini_graph.ttl')
